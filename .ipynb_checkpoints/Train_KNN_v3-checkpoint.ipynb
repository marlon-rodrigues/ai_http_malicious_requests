# %%
import sys
import os
import json
import pandas
import numpy
import optparse
from keras.callbacks import TensorBoard
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from collections import OrderedDict
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
requests_data = pandas.read_csv('Datasets/output_http_csic_2010_full.csv')
#requests_data = requests_data.sample(10)
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
requests_data
# Out:
#         index method                                                url  \
# 0           0    GET   http://localhost:8080/tienda1/publico/anadir.jsp
# 1           0    GET   http://localhost:8080/tienda1/publico/anadir.jsp
# 2           0    GET   http://localhost:8080/tienda1/publico/anadir.jsp
# 3           0    GET   http://localhost:8080/tienda1/publico/anadir.jsp
# 4           0    GET   http://localhost:8080/tienda1/publico/anadir.jsp
# 5           1    GET   http://localhost:8080/tienda1/publico/anadir.jsp
# 6           1    GET   http://localhost:8080/tienda1/publico/anadir.jsp
# 7           1    GET   http://localhost:8080/tienda1/publico/anadir.jsp
# 8           1    GET   http://localhost:8080/tienda1/publico/anadir.jsp
# 9           1    GET   http://localhost:8080/tienda1/publico/anadir.jsp
# 10          2    GET           http://localhost:8080/asf-logo-wide.gif~
# 11          3    GET  http://localhost:8080/tienda1/publico/autentic...
# 12          3    GET  http://localhost:8080/tienda1/publico/autentic...
# 13          3    GET  http://localhost:8080/tienda1/publico/autentic...
# 14          3    GET  http://localhost:8080/tienda1/publico/autentic...
# 15          3    GET  http://localhost:8080/tienda1/publico/autentic...
# 16          4    GET  http://localhost:8080/tienda1/publico/autentic...
# 17          4    GET  http://localhost:8080/tienda1/publico/autentic...
# 18          4    GET  http://localhost:8080/tienda1/publico/autentic...
# 19          4    GET  http://localhost:8080/tienda1/publico/autentic...
# 20          4    GET  http://localhost:8080/tienda1/publico/autentic...
# 21          5    GET  http://localhost:8080/tienda1/publico/autentic...
# 22          5    GET  http://localhost:8080/tienda1/publico/autentic...
# 23          5    GET  http://localhost:8080/tienda1/publico/autentic...
# 24          5    GET  http://localhost:8080/tienda1/publico/autentic...
# 25          5    GET  http://localhost:8080/tienda1/publico/autentic...
# 26          6    GET  http://localhost:8080/tienda1/publico/caracter...
# 27          7    GET   http://localhost:8080/tienda1/publico/entrar.jsp
# 28          8    GET   http://localhost:8080/tienda1/publico/entrar.jsp
# 29          9    GET  http://localhost:8080/IISSamples/sdk/asp/appli...
# ...       ...    ...                                                ...
# 223555  35996   POST    http://localhost:8080/tienda1/publico/pagar.jsp
# 223556  35996   POST    http://localhost:8080/tienda1/publico/pagar.jsp
# 223557  35996   POST    http://localhost:8080/tienda1/publico/pagar.jsp
# 223558  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223559  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223560  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223561  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223562  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223563  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223564  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223565  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223566  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223567  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223568  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223569  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223570  35997   POST  http://localhost:8080/tienda1/publico/registro...
# 223571  35998   POST   http://localhost:8080/tienda1/publico/vaciar.jsp
# 223572  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223573  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223574  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223575  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223576  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223577  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223578  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223579  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223580  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223581  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223582  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223583  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
# 223584  35999   POST  http://localhost:8080/tienda1/miembros/editar.jsp
#
#         protocol                                          userAgent    pragma  \
# 0       HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 1       HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 2       HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 3       HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 4       HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 5       HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 6       HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 7       HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 8       HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9       HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 10      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 11      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 12      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 13      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 14      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 15      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 16      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 17      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 18      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 19      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 20      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 21      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 22      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 23      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 24      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 25      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 26      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 27      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 28      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 29      HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# ...          ...                                                ...       ...
# 223555  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223556  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223557  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223558  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223559  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223560  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223561  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223562  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223563  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223564  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223565  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223566  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223567  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223568  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223569  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223570  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223571  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223572  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223573  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223574  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223575  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223576  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223577  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223578  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223579  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223580  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223581  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223582  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223583  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 223584  HTTP/1.1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
#
#        cacheControl                                             accept  \
# 0          no-cache  text/xml,application/xml,application/xhtml+xml...
# 1          no-cache  text/xml,application/xml,application/xhtml+xml...
# 2          no-cache  text/xml,application/xml,application/xhtml+xml...
# 3          no-cache  text/xml,application/xml,application/xhtml+xml...
# 4          no-cache  text/xml,application/xml,application/xhtml+xml...
# 5          no-cache  text/xml,application/xml,application/xhtml+xml...
# 6          no-cache  text/xml,application/xml,application/xhtml+xml...
# 7          no-cache  text/xml,application/xml,application/xhtml+xml...
# 8          no-cache  text/xml,application/xml,application/xhtml+xml...
# 9          no-cache  text/xml,application/xml,application/xhtml+xml...
# 10         no-cache  text/xml,application/xml,application/xhtml+xml...
# 11         no-cache  text/xml,application/xml,application/xhtml+xml...
# 12         no-cache  text/xml,application/xml,application/xhtml+xml...
# 13         no-cache  text/xml,application/xml,application/xhtml+xml...
# 14         no-cache  text/xml,application/xml,application/xhtml+xml...
# 15         no-cache  text/xml,application/xml,application/xhtml+xml...
# 16         no-cache  text/xml,application/xml,application/xhtml+xml...
# 17         no-cache  text/xml,application/xml,application/xhtml+xml...
# 18         no-cache  text/xml,application/xml,application/xhtml+xml...
# 19         no-cache  text/xml,application/xml,application/xhtml+xml...
# 20         no-cache  text/xml,application/xml,application/xhtml+xml...
# 21         no-cache  text/xml,application/xml,application/xhtml+xml...
# 22         no-cache  text/xml,application/xml,application/xhtml+xml...
# 23         no-cache  text/xml,application/xml,application/xhtml+xml...
# 24         no-cache  text/xml,application/xml,application/xhtml+xml...
# 25         no-cache  text/xml,application/xml,application/xhtml+xml...
# 26         no-cache  text/xml,application/xml,application/xhtml+xml...
# 27         no-cache  text/xml,application/xml,application/xhtml+xml...
# 28         no-cache  text/xml,application/xml,application/xhtml+xml...
# 29         no-cache  text/xml,application/xml,application/xhtml+xml...
# ...             ...                                                ...
# 223555     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223556     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223557     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223558     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223559     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223560     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223561     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223562     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223563     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223564     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223565     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223566     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223567     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223568     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223569     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223570     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223571     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223572     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223573     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223574     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223575     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223576     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223577     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223578     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223579     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223580     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223581     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223582     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223583     no-cache  text/xml,application/xml,application/xhtml+xml...
# 223584     no-cache  text/xml,application/xml,application/xhtml+xml...
#
#                           acceptEncoding                acceptCharset  \
# 0       x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 1       x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 2       x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 3       x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 4       x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 5       x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 6       x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 7       x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 8       x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 9       x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 10      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 11      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 12      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 13      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 14      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 15      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 16      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 17      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 18      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 19      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 20      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 21      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 22      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 23      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 24      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 25      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 26      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 27      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 28      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 29      x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# ...                                  ...                          ...
# 223555  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223556  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223557  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223558  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223559  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223560  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223561  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223562  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223563  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223564  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223565  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223566  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223567  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223568  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223569  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223570  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223571  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223572  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223573  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223574  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223575  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223576  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223577  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223578  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223579  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223580  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223581  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223582  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223583  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 223584  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
#
#        acceptLanguage            host connection  contentLength  \
# 0                  en  localhost:8080      close            NaN
# 1                  en  localhost:8080      close            NaN
# 2                  en  localhost:8080      close            NaN
# 3                  en  localhost:8080      close            NaN
# 4                  en  localhost:8080      close            NaN
# 5                  en  localhost:8080      close            NaN
# 6                  en  localhost:8080      close            NaN
# 7                  en  localhost:8080      close            NaN
# 8                  en  localhost:8080      close            NaN
# 9                  en  localhost:8080      close            NaN
# 10                 en  localhost:8080      close            NaN
# 11                 en  localhost:8080      close            NaN
# 12                 en  localhost:8080      close            NaN
# 13                 en  localhost:8080      close            NaN
# 14                 en  localhost:8080      close            NaN
# 15                 en  localhost:8080      close            NaN
# 16                 en  localhost:8080      close            NaN
# 17                 en  localhost:8080      close            NaN
# 18                 en  localhost:8080      close            NaN
# 19                 en  localhost:8080      close            NaN
# 20                 en  localhost:8080      close            NaN
# 21                 en  localhost:8080      close            NaN
# 22                 en  localhost:8080      close            NaN
# 23                 en  localhost:8080      close            NaN
# 24                 en  localhost:8080      close            NaN
# 25                 en  localhost:8080      close            NaN
# 26                 en  localhost:8080      close            NaN
# 27                 en  localhost:8080      close            NaN
# 28                 en  localhost:8080      close            NaN
# 29                 en  localhost:8080      close            NaN
# ...               ...             ...        ...            ...
# 223555             en  localhost:8080      close           43.0
# 223556             en  localhost:8080      close           43.0
# 223557             en  localhost:8080      close           43.0
# 223558             en  localhost:8080      close          250.0
# 223559             en  localhost:8080      close          250.0
# 223560             en  localhost:8080      close          250.0
# 223561             en  localhost:8080      close          250.0
# 223562             en  localhost:8080      close          250.0
# 223563             en  localhost:8080      close          250.0
# 223564             en  localhost:8080      close          250.0
# 223565             en  localhost:8080      close          250.0
# 223566             en  localhost:8080      close          250.0
# 223567             en  localhost:8080      close          250.0
# 223568             en  localhost:8080      close          250.0
# 223569             en  localhost:8080      close          250.0
# 223570             en  localhost:8080      close          250.0
# 223571             en  localhost:8080      close           17.0
# 223572             en  localhost:8080      close          238.0
# 223573             en  localhost:8080      close          238.0
# 223574             en  localhost:8080      close          238.0
# 223575             en  localhost:8080      close          238.0
# 223576             en  localhost:8080      close          238.0
# 223577             en  localhost:8080      close          238.0
# 223578             en  localhost:8080      close          238.0
# 223579             en  localhost:8080      close          238.0
# 223580             en  localhost:8080      close          238.0
# 223581             en  localhost:8080      close          238.0
# 223582             en  localhost:8080      close          238.0
# 223583             en  localhost:8080      close          238.0
# 223584             en  localhost:8080      close          238.0
#
#                               contentType  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# ...                                   ...
# 223555  application/x-www-form-urlencoded
# 223556  application/x-www-form-urlencoded
# 223557  application/x-www-form-urlencoded
# 223558  application/x-www-form-urlencoded
# 223559  application/x-www-form-urlencoded
# 223560  application/x-www-form-urlencoded
# 223561  application/x-www-form-urlencoded
# 223562  application/x-www-form-urlencoded
# 223563  application/x-www-form-urlencoded
# 223564  application/x-www-form-urlencoded
# 223565  application/x-www-form-urlencoded
# 223566  application/x-www-form-urlencoded
# 223567  application/x-www-form-urlencoded
# 223568  application/x-www-form-urlencoded
# 223569  application/x-www-form-urlencoded
# 223570  application/x-www-form-urlencoded
# 223571  application/x-www-form-urlencoded
# 223572  application/x-www-form-urlencoded
# 223573  application/x-www-form-urlencoded
# 223574  application/x-www-form-urlencoded
# 223575  application/x-www-form-urlencoded
# 223576  application/x-www-form-urlencoded
# 223577  application/x-www-form-urlencoded
# 223578  application/x-www-form-urlencoded
# 223579  application/x-www-form-urlencoded
# 223580  application/x-www-form-urlencoded
# 223581  application/x-www-form-urlencoded
# 223582  application/x-www-form-urlencoded
# 223583  application/x-www-form-urlencoded
# 223584  application/x-www-form-urlencoded
#
#                                              cookie  \
# 0       JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 1       JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 2       JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 3       JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 4       JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 5       JSESSIONID=F563B5262843F12ECAE41815ABDEEA54
# 6       JSESSIONID=F563B5262843F12ECAE41815ABDEEA54
# 7       JSESSIONID=F563B5262843F12ECAE41815ABDEEA54
# 8       JSESSIONID=F563B5262843F12ECAE41815ABDEEA54
# 9       JSESSIONID=F563B5262843F12ECAE41815ABDEEA54
# 10      JSESSIONID=51A7470173188BBB993947F2283059E4
# 11      JSESSIONID=AC0EEEDD09663CB36C67DD1B787B0CF5
# 12      JSESSIONID=AC0EEEDD09663CB36C67DD1B787B0CF5
# 13      JSESSIONID=AC0EEEDD09663CB36C67DD1B787B0CF5
# 14      JSESSIONID=AC0EEEDD09663CB36C67DD1B787B0CF5
# 15      JSESSIONID=AC0EEEDD09663CB36C67DD1B787B0CF5
# 16      JSESSIONID=0FCF23BE3D0EB007F5289208CE069EAA
# 17      JSESSIONID=0FCF23BE3D0EB007F5289208CE069EAA
# 18      JSESSIONID=0FCF23BE3D0EB007F5289208CE069EAA
# 19      JSESSIONID=0FCF23BE3D0EB007F5289208CE069EAA
# 20      JSESSIONID=0FCF23BE3D0EB007F5289208CE069EAA
# 21      JSESSIONID=09BF818C8B6E9EFE9DF5F28745D5948B
# 22      JSESSIONID=09BF818C8B6E9EFE9DF5F28745D5948B
# 23      JSESSIONID=09BF818C8B6E9EFE9DF5F28745D5948B
# 24      JSESSIONID=09BF818C8B6E9EFE9DF5F28745D5948B
# 25      JSESSIONID=09BF818C8B6E9EFE9DF5F28745D5948B
# 26      JSESSIONID=7FD36920003C837664CF0EF535DC10B9
# 27      JSESSIONID=ACB274547804B328DC6E8A6437B330B9
# 28      JSESSIONID=C0E8CC9BE76123330EEEC0896621D656
# 29      JSESSIONID=7A7810BAEDA706C77CC9C2F19311BFB5
# ...                                             ...
# 223555  JSESSIONID=689F776825502AB01C8C2197AEC18983
# 223556  JSESSIONID=689F776825502AB01C8C2197AEC18983
# 223557  JSESSIONID=689F776825502AB01C8C2197AEC18983
# 223558  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223559  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223560  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223561  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223562  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223563  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223564  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223565  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223566  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223567  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223568  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223569  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223570  JSESSIONID=C6B5D82171F2ADBEF3E49FB0045DACF9
# 223571  JSESSIONID=918D48178153C0719EC7B00270E22128
# 223572  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223573  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223574  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223575  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223576  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223577  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223578  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223579  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223580  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223581  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223582  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223583  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
# 223584  JSESSIONID=05C0977CEA3691A57DFC74F2A03C3D2C
#
#                                                   payload label
# 0                                                    id=2  anom
# 1                                nombre=Jam%F3n+Ib%E9rico  anom
# 2                                               precio=85  anom
# 3       cantidad=%27%3B+DROP+TABLE+usuarios%3B+SELECT+...  anom
# 4                                  B1=A%F1adir+al+carrito  anom
# 5                                                 id=2%2F  anom
# 6                                nombre=Jam%F3n+Ib%E9rico  anom
# 7                                               precio=85  anom
# 8                                             cantidad=49  anom
# 9                                  B1=A%F1adir+al+carrito  anom
# 10                                                    NaN  anom
# 11                                            modo=entrar  anom
# 12      login=bob%40%3CSCRipt%3Ealert%28Paros%29%3C%2F...  anom
# 13                                          pwd=84m3ri156  anom
# 14                                            remember=on  anom
# 15                                              B1=Entrar  anom
# 16                                            modo=entrar  anom
# 17                                         login=grimshaw  anom
# 18                                   pwd=G%2F%2FlAc%2CIAr  anom
# 19                                            remember=on  anom
# 20                                              B1=Entrar  anom
# 21                                            modo=entrar  anom
# 22                                         login=grimshaw  anom
# 23                                          pwd=84m3ri156  anom
# 24                                           rememberA=on  anom
# 25                                              B1=Entrar  anom
# 26                                                  idA=2  anom
# 27                                           errorMsg=%2B  anom
# 28                     errorMsgA=Credenciales+incorrectas  anom
# 29                                                    NaN  anom
# ...                                                   ...   ...
# 223555                                      modo=insertar  norm
# 223556                                        precio=6460  norm
# 223557                                  B1=Pasar+por+caja  norm
# 223558                                      modo=registro  norm
# 223559                                      login=xaviera  norm
# 223560                                 password=och*avero  norm
# 223561                                  nombre=Florestano  norm
# 223562                          apellidos=Alegre+Nomdedeu  norm
# 223563             email=pianka%40noviasteresapalacios.mc  norm
# 223564                                      dni=42798379W  norm
# 223565                    direccion=Calle+Estafeta+105+6C  norm
# 223566                                     ciudad=Entrala  norm
# 223567                                           cp=47800  norm
# 223568                                   provincia=Burgos  norm
# 223569                               ntc=2111805626623658  norm
# 223570                                       B1=Registrar  norm
# 223571                                  B2=Vaciar+carrito  norm
# 223572                                      modo=registro  norm
# 223573                                     login=palidwor  norm
# 223574                               password=AtL%C1ntiCa  norm
# 223575                                    nombre=Vazk%E9n  norm
# 223576                                  apellidos=Bernaus  norm
# 223577                       email=carras%40quiromante.vi  norm
# 223578                                      dni=29061025L  norm
# 223579                 direccion=Calle+Manzanilla+141%2C+  norm
# 223580                                   ciudad=Hontangas  norm
# 223581                                           cp=08192  norm
# 223582                                   provincia=Teruel  norm
# 223583                               ntc=8231060336250168  norm
# 223584                                       B1=Registrar  norm
#
# [223585 rows x 18 columns]

# %%
col = ['payload', 'label']
requests_data = requests_data[col]
requests_data = requests_data[pandas.notnull(requests_data['payload'])]
requests_data
# Out:
#                                                   payload label
# 0                                                    id=2  anom
# 1                                nombre=Jam%F3n+Ib%E9rico  anom
# 2                                               precio=85  anom
# 3       cantidad=%27%3B+DROP+TABLE+usuarios%3B+SELECT+...  anom
# 4                                  B1=A%F1adir+al+carrito  anom
# 5                                                 id=2%2F  anom
# 6                                nombre=Jam%F3n+Ib%E9rico  anom
# 7                                               precio=85  anom
# 8                                             cantidad=49  anom
# 9                                  B1=A%F1adir+al+carrito  anom
# 11                                            modo=entrar  anom
# 12      login=bob%40%3CSCRipt%3Ealert%28Paros%29%3C%2F...  anom
# 13                                          pwd=84m3ri156  anom
# 14                                            remember=on  anom
# 15                                              B1=Entrar  anom
# 16                                            modo=entrar  anom
# 17                                         login=grimshaw  anom
# 18                                   pwd=G%2F%2FlAc%2CIAr  anom
# 19                                            remember=on  anom
# 20                                              B1=Entrar  anom
# 21                                            modo=entrar  anom
# 22                                         login=grimshaw  anom
# 23                                          pwd=84m3ri156  anom
# 24                                           rememberA=on  anom
# 25                                              B1=Entrar  anom
# 26                                                  idA=2  anom
# 27                                           errorMsg=%2B  anom
# 28                     errorMsgA=Credenciales+incorrectas  anom
# 30                                          modo=insertar  anom
# 31      precio=183%27%2C%270%27%2C%270%27%29%3Bwaitfor...  anom
# ...                                                   ...   ...
# 223555                                      modo=insertar  norm
# 223556                                        precio=6460  norm
# 223557                                  B1=Pasar+por+caja  norm
# 223558                                      modo=registro  norm
# 223559                                      login=xaviera  norm
# 223560                                 password=och*avero  norm
# 223561                                  nombre=Florestano  norm
# 223562                          apellidos=Alegre+Nomdedeu  norm
# 223563             email=pianka%40noviasteresapalacios.mc  norm
# 223564                                      dni=42798379W  norm
# 223565                    direccion=Calle+Estafeta+105+6C  norm
# 223566                                     ciudad=Entrala  norm
# 223567                                           cp=47800  norm
# 223568                                   provincia=Burgos  norm
# 223569                               ntc=2111805626623658  norm
# 223570                                       B1=Registrar  norm
# 223571                                  B2=Vaciar+carrito  norm
# 223572                                      modo=registro  norm
# 223573                                     login=palidwor  norm
# 223574                               password=AtL%C1ntiCa  norm
# 223575                                    nombre=Vazk%E9n  norm
# 223576                                  apellidos=Bernaus  norm
# 223577                       email=carras%40quiromante.vi  norm
# 223578                                      dni=29061025L  norm
# 223579                 direccion=Calle+Manzanilla+141%2C+  norm
# 223580                                   ciudad=Hontangas  norm
# 223581                                           cp=08192  norm
# 223582                                   provincia=Teruel  norm
# 223583                               ntc=8231060336250168  norm
# 223584                                       B1=Registrar  norm
#
# [198094 rows x 2 columns]

# %%
requests_data['label_id'] = requests_data['label'].factorize()[0]

from io import StringIO
label_id_df = requests_data[['payload', 'label_id']].drop_duplicates().sort_values('label_id')
label_to_id = dict(label_id_df.values)
id_to_label = dict(label_id_df[['label_id', 'payload']].values)

# %%
requests_data
# Out:
#                                                   payload label  label_id
# 0                                                    id=2  anom         0
# 1                                nombre=Jam%F3n+Ib%E9rico  anom         0
# 2                                               precio=85  anom         0
# 3       cantidad=%27%3B+DROP+TABLE+usuarios%3B+SELECT+...  anom         0
# 4                                  B1=A%F1adir+al+carrito  anom         0
# 5                                                 id=2%2F  anom         0
# 6                                nombre=Jam%F3n+Ib%E9rico  anom         0
# 7                                               precio=85  anom         0
# 8                                             cantidad=49  anom         0
# 9                                  B1=A%F1adir+al+carrito  anom         0
# 11                                            modo=entrar  anom         0
# 12      login=bob%40%3CSCRipt%3Ealert%28Paros%29%3C%2F...  anom         0
# 13                                          pwd=84m3ri156  anom         0
# 14                                            remember=on  anom         0
# 15                                              B1=Entrar  anom         0
# 16                                            modo=entrar  anom         0
# 17                                         login=grimshaw  anom         0
# 18                                   pwd=G%2F%2FlAc%2CIAr  anom         0
# 19                                            remember=on  anom         0
# 20                                              B1=Entrar  anom         0
# 21                                            modo=entrar  anom         0
# 22                                         login=grimshaw  anom         0
# 23                                          pwd=84m3ri156  anom         0
# 24                                           rememberA=on  anom         0
# 25                                              B1=Entrar  anom         0
# 26                                                  idA=2  anom         0
# 27                                           errorMsg=%2B  anom         0
# 28                     errorMsgA=Credenciales+incorrectas  anom         0
# 30                                          modo=insertar  anom         0
# 31      precio=183%27%2C%270%27%2C%270%27%29%3Bwaitfor...  anom         0
# ...                                                   ...   ...       ...
# 223555                                      modo=insertar  norm         1
# 223556                                        precio=6460  norm         1
# 223557                                  B1=Pasar+por+caja  norm         1
# 223558                                      modo=registro  norm         1
# 223559                                      login=xaviera  norm         1
# 223560                                 password=och*avero  norm         1
# 223561                                  nombre=Florestano  norm         1
# 223562                          apellidos=Alegre+Nomdedeu  norm         1
# 223563             email=pianka%40noviasteresapalacios.mc  norm         1
# 223564                                      dni=42798379W  norm         1
# 223565                    direccion=Calle+Estafeta+105+6C  norm         1
# 223566                                     ciudad=Entrala  norm         1
# 223567                                           cp=47800  norm         1
# 223568                                   provincia=Burgos  norm         1
# 223569                               ntc=2111805626623658  norm         1
# 223570                                       B1=Registrar  norm         1
# 223571                                  B2=Vaciar+carrito  norm         1
# 223572                                      modo=registro  norm         1
# 223573                                     login=palidwor  norm         1
# 223574                               password=AtL%C1ntiCa  norm         1
# 223575                                    nombre=Vazk%E9n  norm         1
# 223576                                  apellidos=Bernaus  norm         1
# 223577                       email=carras%40quiromante.vi  norm         1
# 223578                                      dni=29061025L  norm         1
# 223579                 direccion=Calle+Manzanilla+141%2C+  norm         1
# 223580                                   ciudad=Hontangas  norm         1
# 223581                                           cp=08192  norm         1
# 223582                                   provincia=Teruel  norm         1
# 223583                               ntc=8231060336250168  norm         1
# 223584                                       B1=Registrar  norm         1
#
# [198094 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
requests_data.groupby('label').payload.count().plot.bar(ylim=0)
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=2, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

features = tfidf.fit_transform(requests_data.payload).toarray()
labels = requests_data.label_id
features.shape
# Out:
# (198094, 85296)

# %%
from sklearn.feature_selection import chi2
import numpy as np

N = 2
for payload, label_id in sorted(label_to_id.items()):
  features_chi2 = chi2(features, labels == label_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(label_id))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

X_train, X_test, y_train, y_test = train_test_split(requests_data['payload'], requests_data['label_id'], test_size=0.25, random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
clf.predict(count_vect.transform(X_test))

# %%
print(clf.predict(count_vect.transform(["B2=Test123&BLA='dasdas'&TEST"])))
# Out:
# [1]

# %%
# instantiate learning model (k = 3)
knn = KNeighborsClassifier(n_neighbors=3)

# fitting the model
knn.fit(X_train_tfidf, y_train)

# predict the response
pred = knn.predict(count_vect.transform(X_test))

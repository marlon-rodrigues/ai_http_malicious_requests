# %%
import sys
import os
import json
import pandas
import numpy
import optparse
from keras.callbacks import TensorBoard
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from collections import OrderedDict
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
requests_data = pandas.read_csv('Datasets/all_requests_csv.csv', error_bad_lines=False, header=None)

# %%
requests_data = requests_data.iloc[1:]
requests_data.columns = ['payload', 'label_id', 'label']
requests_data
# Out:
#                                                  payload label_id    label
# 2      modo=entrar&login=choong&pwd=d1se3ci%F3n&remem...        0   normal
# 3                                                   id=2        0   normal
# 4                      errorMsg=Credenciales+incorrectas        0   normal
# 5            modo=insertar&precio=2672&B1=Pasar+por+caja        0   normal
# 6      modo=registro&login=cen&password=40a5E&nombre=...        0   normal
# 7                                      B2=Vaciar+carrito        0   normal
# 8      modo=registro&login=de_la&password=roder%F3n&n...        0   normal
# 9      id=3&nombre=Queso+Manchego&precio=100&cantidad...        0   normal
# 10     modo=entrar&login=magrath&pwd=1an0re%E15354&re...        0   normal
# 11                                                  id=1        0   normal
# 12                     errorMsg=Credenciales+incorrectas        0   normal
# 13            modo=insertar&precio=958&B1=Pasar+por+caja        0   normal
# 14     modo=registro&login=francois&password=patay&no...        0   normal
# 15                                     B2=Vaciar+carrito        0   normal
# 16     modo=registro&login=misczak&password=prestamen...        0   normal
# 17     id=1&nombre=Queso+Manchego&precio=39&cantidad=...        0   normal
# 18     modo=entrar&login=quinn&pwd=incisivo&remember=...        0   normal
# 19                                                  id=2        0   normal
# 20                     errorMsg=Credenciales+incorrectas        0   normal
# 21           modo=insertar&precio=6429&B1=Pasar+por+caja        0   normal
# 22     modo=registro&login=del&password=repulsivo&nom...        0   normal
# 23                                     B2=Vaciar+carrito        0   normal
# 24     modo=registro&login=pacon&password=protoalb%E9...        0   normal
# 25     id=1&nombre=Vino+Rioja&precio=39&cantidad=25&B...        0   normal
# 26     modo=entrar&login=aguistin&pwd=iNnota&remember...        0   normal
# 27                                                  id=2        0   normal
# 28                     errorMsg=Credenciales+incorrectas        0   normal
# 29                modo=insertar&precio=1499&B1=Confirmar        0   normal
# 30     modo=registro&login=verde&password=er6%E1til&n...        0   normal
# 31                                     B2=Vaciar+carrito        0   normal
# ...                                                  ...      ...      ...
# 14409  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14410  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14411  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14412  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14413  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14414  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14415  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14416  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14417  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14418  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14419  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14420  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14421  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14422  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14423  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14424  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14425  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14426  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14427  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14428  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14429  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14430  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14431  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14432  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14433  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14434  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14435  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14436  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14437  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14438  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
#
# [14437 rows x 3 columns]

# %%
requests_data = requests_data[pandas.notnull(requests_data['payload'])]
requests_data
# Out:
#                                                  payload label_id    label
# 2      modo=entrar&login=choong&pwd=d1se3ci%F3n&remem...        0   normal
# 3                                                   id=2        0   normal
# 4                      errorMsg=Credenciales+incorrectas        0   normal
# 5            modo=insertar&precio=2672&B1=Pasar+por+caja        0   normal
# 6      modo=registro&login=cen&password=40a5E&nombre=...        0   normal
# 7                                      B2=Vaciar+carrito        0   normal
# 8      modo=registro&login=de_la&password=roder%F3n&n...        0   normal
# 9      id=3&nombre=Queso+Manchego&precio=100&cantidad...        0   normal
# 10     modo=entrar&login=magrath&pwd=1an0re%E15354&re...        0   normal
# 11                                                  id=1        0   normal
# 12                     errorMsg=Credenciales+incorrectas        0   normal
# 13            modo=insertar&precio=958&B1=Pasar+por+caja        0   normal
# 14     modo=registro&login=francois&password=patay&no...        0   normal
# 15                                     B2=Vaciar+carrito        0   normal
# 16     modo=registro&login=misczak&password=prestamen...        0   normal
# 17     id=1&nombre=Queso+Manchego&precio=39&cantidad=...        0   normal
# 18     modo=entrar&login=quinn&pwd=incisivo&remember=...        0   normal
# 19                                                  id=2        0   normal
# 20                     errorMsg=Credenciales+incorrectas        0   normal
# 21           modo=insertar&precio=6429&B1=Pasar+por+caja        0   normal
# 22     modo=registro&login=del&password=repulsivo&nom...        0   normal
# 23                                     B2=Vaciar+carrito        0   normal
# 24     modo=registro&login=pacon&password=protoalb%E9...        0   normal
# 25     id=1&nombre=Vino+Rioja&precio=39&cantidad=25&B...        0   normal
# 26     modo=entrar&login=aguistin&pwd=iNnota&remember...        0   normal
# 27                                                  id=2        0   normal
# 28                     errorMsg=Credenciales+incorrectas        0   normal
# 29                modo=insertar&precio=1499&B1=Confirmar        0   normal
# 30     modo=registro&login=verde&password=er6%E1til&n...        0   normal
# 31                                     B2=Vaciar+carrito        0   normal
# ...                                                  ...      ...      ...
# 14409  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14410  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14411  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14412  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14413  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14414  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14415  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14416  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14417  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14418  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14419  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14420  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14421  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14422  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14423  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14424  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14425  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14426  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14427  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14428  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14429  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14430  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14431  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14432  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14433  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14434  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14435  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14436  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14437  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14438  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
#
# [14437 rows x 3 columns]

# %%
#requests_data['label_id'] = requests_data['label'].factorize()[0]

#from io import StringIO
#label_id_df = requests_data[['payload', 'label_id']].drop_duplicates().sort_values('label_id')
#label_to_id = dict(label_id_df.values)
#id_to_label = dict(label_id_df[['label_id', 'payload']].values)

# %%
requests_data
# Out:
#                                                  payload label_id    label
# 2      modo=entrar&login=choong&pwd=d1se3ci%F3n&remem...        0   normal
# 3                                                   id=2        0   normal
# 4                      errorMsg=Credenciales+incorrectas        0   normal
# 5            modo=insertar&precio=2672&B1=Pasar+por+caja        0   normal
# 6      modo=registro&login=cen&password=40a5E&nombre=...        0   normal
# 7                                      B2=Vaciar+carrito        0   normal
# 8      modo=registro&login=de_la&password=roder%F3n&n...        0   normal
# 9      id=3&nombre=Queso+Manchego&precio=100&cantidad...        0   normal
# 10     modo=entrar&login=magrath&pwd=1an0re%E15354&re...        0   normal
# 11                                                  id=1        0   normal
# 12                     errorMsg=Credenciales+incorrectas        0   normal
# 13            modo=insertar&precio=958&B1=Pasar+por+caja        0   normal
# 14     modo=registro&login=francois&password=patay&no...        0   normal
# 15                                     B2=Vaciar+carrito        0   normal
# 16     modo=registro&login=misczak&password=prestamen...        0   normal
# 17     id=1&nombre=Queso+Manchego&precio=39&cantidad=...        0   normal
# 18     modo=entrar&login=quinn&pwd=incisivo&remember=...        0   normal
# 19                                                  id=2        0   normal
# 20                     errorMsg=Credenciales+incorrectas        0   normal
# 21           modo=insertar&precio=6429&B1=Pasar+por+caja        0   normal
# 22     modo=registro&login=del&password=repulsivo&nom...        0   normal
# 23                                     B2=Vaciar+carrito        0   normal
# 24     modo=registro&login=pacon&password=protoalb%E9...        0   normal
# 25     id=1&nombre=Vino+Rioja&precio=39&cantidad=25&B...        0   normal
# 26     modo=entrar&login=aguistin&pwd=iNnota&remember...        0   normal
# 27                                                  id=2        0   normal
# 28                     errorMsg=Credenciales+incorrectas        0   normal
# 29                modo=insertar&precio=1499&B1=Confirmar        0   normal
# 30     modo=registro&login=verde&password=er6%E1til&n...        0   normal
# 31                                     B2=Vaciar+carrito        0   normal
# ...                                                  ...      ...      ...
# 14409  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14410  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14411  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14412  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14413  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14414  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14415  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14416  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14417  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14418  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14419  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14420  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14421  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14422  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14423  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14424  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14425  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14426  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14427  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14428  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14429  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14430  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14431  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14432  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14433  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14434  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14435  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14436  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14437  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
# 14438  searchText=&tenantKey=61&timeRangeScalar=1&tim...        1  anomaly
#
# [14437 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
requests_data.groupby('label').payload.count().plot.bar(ylim=0)
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=2, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

features = tfidf.fit_transform(requests_data.payload).toarray()
labels = requests_data.label_id
features.shape
# Out:
# (14437, 24666)

# %%
#from sklearn.feature_selection import chi2
#import numpy as np

#N = 2
#for payload, label_id in sorted(label_to_id.items()):
#  features_chi2 = chi2(features, labels == label_id)
#  indices = np.argsort(features_chi2[0])
#  feature_names = np.array(tfidf.get_feature_names())[indices]
#  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
#  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
#  print("# '{}':".format(label_id))
#  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
#  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

X_train, X_test, y_train, y_test = train_test_split(requests_data['payload'], requests_data['label_id'], test_size=0.25, random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
pred = clf.predict(count_vect.transform(X_test))

# %%
# Evaluate the prediction accuracy of the model
from sklearn import metrics

print("The Explained Variance: %.2f" % clf.score(count_vect.transform(X_test), y_test))  
print("The Mean Absolute Error: " % metrics.mean_absolute_error(y_test, pred))  
print("The Median Absolute Error: " % metrics.median_absolute_error(y_test, pred)) 
print("The Mean Squared Error: " % metrics.mean_squared_error(y_test, pred)) 
print("The Root Mean Squared Error: " % (numpy.sqrt(metrics.mean_squared_error(y_test, pred))))
# Out:
# The Explained Variance: 1.00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-30fb4f464be4> in <module>()
#       3
#       4 print("The Explained Variance: %.2f" % clf.score(count_vect.transform(X_test), y_test))
# ----> 5 print("The Mean Absolute Error: " % metrics.mean_absolute_error(y_test, pred))
#       6 print("The Median Absolute Error: " % metrics.median_absolute_error(y_test, pred))
#       7 print("The Mean Squared Error: " % metrics.mean_squared_error(y_test, pred))
#
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     169     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     170         y_true, y_pred, multioutput)
# --> 171     output_errors = np.average(np.abs(y_pred - y_true),
#     172                                weights=sample_weight, axis=0)
#     173     if isinstance(multioutput, string_types):
#
# TypeError: ufunc 'subtract' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')

# %%
print(clf.predict(count_vect.transform(["searchText=name=marlon+and+label=test+and+#Select * from&&#"])))
# Out:
# ['1']

# %%
# instantiate learning model (k = 3)
knn = KNeighborsClassifier(n_neighbors=3)

# fitting the model
knn.fit(X_train_tfidf, y_train)

# predict the response
pred2 = knn.predict(count_vect.transform(X_test))

# %%
print("The Explained Variance: %.2f" % knn.score(count_vect.transform(X_test), y_test))  
print("The Mean Absolute Error: " % metrics.mean_absolute_error(y_test, pred2))  
print("The Median Absolute Error: " % metrics.median_absolute_error(y_test, pred2)) 
print("The Mean Squared Error: " % metrics.mean_squared_error(y_test, pred2)) 
print("The Root Mean Squared Error: " % (numpy.sqrt(metrics.mean_squared_error(y_test, pred2))))
# Out:
# The Explained Variance: 1.00
# The Mean Absolute Error:
# The Median Absolute Error:
# The Mean Squared Error:
# The Root Mean Squared Error:

# %%
print(knn.predict(count_vect.transform(["searchText='id=3&name=Marlon"])))
# Out:
# ['0']

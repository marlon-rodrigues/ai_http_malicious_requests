# %%
import sys
import os
import json
import pandas
import numpy
import optparse
from keras.callbacks import TensorBoard
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from collections import OrderedDict
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
requests_data = pandas.read_csv('Datasets/output_http_csic_2010_full.csv')
requests_data.head(5)
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    index method                                               url  protocol  \
# 0      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 1      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 2      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 3      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 4      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
#
#                                            userAgent    pragma cacheControl  \
# 0  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 2  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 3  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 4  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
#
#                                               accept  \
# 0  text/xml,application/xml,application/xhtml+xml...
# 1  text/xml,application/xml,application/xhtml+xml...
# 2  text/xml,application/xml,application/xhtml+xml...
# 3  text/xml,application/xml,application/xhtml+xml...
# 4  text/xml,application/xml,application/xhtml+xml...
#
#                      acceptEncoding                acceptCharset  \
# 0  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 1  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 2  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 3  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 4  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
#
#   acceptLanguage            host connection  contentLength contentType  \
# 0             en  localhost:8080      close            NaN         NaN
# 1             en  localhost:8080      close            NaN         NaN
# 2             en  localhost:8080      close            NaN         NaN
# 3             en  localhost:8080      close            NaN         NaN
# 4             en  localhost:8080      close            NaN         NaN
#
#                                         cookie  \
# 0  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 1  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 2  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 3  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 4  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
#
#                                              payload label
# 0                                               id=2  anom
# 1                           nombre=Jam%F3n+Ib%E9rico  anom
# 2                                          precio=85  anom
# 3  cantidad=%27%3B+DROP+TABLE+usuarios%3B+SELECT+...  anom
# 4                             B1=A%F1adir+al+carrito  anom

# %%
# Create dictionary
requests_data = requests_data.fillna( 'NA' )
requests_dic = requests_data.to_dict( orient = 'records' )

# %%
requests_dic
# Out:
# [{'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=B92A8B48B9008CD29F622A994E0F650D',
#   'host': 'localhost:8080',
#   'index': 0,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'id=2',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/anadir.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=B92A8B48B9008CD29F622A994E0F650D',
#   'host': 'localhost:8080',
#   'index': 0,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'nombre=Jam%F3n+Ib%E9rico',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/anadir.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=B92A8B48B9008CD29F622A994E0F650D',
#   'host': 'localhost:8080',
#   'index': 0,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'precio=85',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/anadir.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=B92A8B48B9008CD29F622A994E0F650D',
#   'host': 'localhost:8080',
#   'index': 0,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'cantidad=%27%3B+DROP+TABLE+usuarios%3B+SELECT+*+FROM+datos+WHERE+nombre+LIKE+%27%25',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/anadir.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=B92A8B48B9008CD29F622A994E0F650D',
#   'host': 'localhost:8080',
#   'index': 0,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=A%F1adir+al+carrito',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/anadir.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=F563B5262843F12ECAE41815ABDEEA54',
#   'host': 'localhost:8080',
#   'index': 1,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'id=2%2F',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/anadir.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=F563B5262843F12ECAE41815ABDEEA54',
#   'host': 'localhost:8080',
#   'index': 1,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'nombre=Jam%F3n+Ib%E9rico',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/anadir.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=F563B5262843F12ECAE41815ABDEEA54',
#   'host': 'localhost:8080',
#   'index': 1,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'precio=85',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/anadir.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=F563B5262843F12ECAE41815ABDEEA54',
#   'host': 'localhost:8080',
#   'index': 1,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'cantidad=49',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/anadir.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=F563B5262843F12ECAE41815ABDEEA54',
#   'host': 'localhost:8080',
#   'index': 1,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=A%F1adir+al+carrito',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/anadir.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=51A7470173188BBB993947F2283059E4',
#   'host': 'localhost:8080',
#   'index': 2,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'NA',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/asf-logo-wide.gif~',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=AC0EEEDD09663CB36C67DD1B787B0CF5',
#   'host': 'localhost:8080',
#   'index': 3,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'modo=entrar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=AC0EEEDD09663CB36C67DD1B787B0CF5',
#   'host': 'localhost:8080',
#   'index': 3,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'login=bob%40%3CSCRipt%3Ealert%28Paros%29%3C%2FscrIPT%3E.parosproxy.org',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=AC0EEEDD09663CB36C67DD1B787B0CF5',
#   'host': 'localhost:8080',
#   'index': 3,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'pwd=84m3ri156',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=AC0EEEDD09663CB36C67DD1B787B0CF5',
#   'host': 'localhost:8080',
#   'index': 3,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'remember=on',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=AC0EEEDD09663CB36C67DD1B787B0CF5',
#   'host': 'localhost:8080',
#   'index': 3,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=Entrar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=0FCF23BE3D0EB007F5289208CE069EAA',
#   'host': 'localhost:8080',
#   'index': 4,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'modo=entrar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=0FCF23BE3D0EB007F5289208CE069EAA',
#   'host': 'localhost:8080',
#   'index': 4,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'login=grimshaw',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=0FCF23BE3D0EB007F5289208CE069EAA',
#   'host': 'localhost:8080',
#   'index': 4,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'pwd=G%2F%2FlAc%2CIAr',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=0FCF23BE3D0EB007F5289208CE069EAA',
#   'host': 'localhost:8080',
#   'index': 4,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'remember=on',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=0FCF23BE3D0EB007F5289208CE069EAA',
#   'host': 'localhost:8080',
#   'index': 4,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=Entrar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=09BF818C8B6E9EFE9DF5F28745D5948B',
#   'host': 'localhost:8080',
#   'index': 5,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'modo=entrar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=09BF818C8B6E9EFE9DF5F28745D5948B',
#   'host': 'localhost:8080',
#   'index': 5,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'login=grimshaw',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=09BF818C8B6E9EFE9DF5F28745D5948B',
#   'host': 'localhost:8080',
#   'index': 5,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'pwd=84m3ri156',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=09BF818C8B6E9EFE9DF5F28745D5948B',
#   'host': 'localhost:8080',
#   'index': 5,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'rememberA=on',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=09BF818C8B6E9EFE9DF5F28745D5948B',
#   'host': 'localhost:8080',
#   'index': 5,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=Entrar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/autenticar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=7FD36920003C837664CF0EF535DC10B9',
#   'host': 'localhost:8080',
#   'index': 6,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'idA=2',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/caracteristicas.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=ACB274547804B328DC6E8A6437B330B9',
#   'host': 'localhost:8080',
#   'index': 7,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'errorMsg=%2B',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/entrar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=C0E8CC9BE76123330EEEC0896621D656',
#   'host': 'localhost:8080',
#   'index': 8,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'errorMsgA=Credenciales+incorrectas',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/entrar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=7A7810BAEDA706C77CC9C2F19311BFB5',
#   'host': 'localhost:8080',
#   'index': 9,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'NA',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/IISSamples/sdk/asp/applications/Application_VBScript.asp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=E59D8FE73AD6F70DC813150199CD4D0B',
#   'host': 'localhost:8080',
#   'index': 10,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'modo=insertar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/pagar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=E59D8FE73AD6F70DC813150199CD4D0B',
#   'host': 'localhost:8080',
#   'index': 10,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'precio=183%27%2C%270%27%2C%270%27%29%3Bwaitfor+delay+%270%3A0%3A15%27%3B--',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/pagar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=E59D8FE73AD6F70DC813150199CD4D0B',
#   'host': 'localhost:8080',
#   'index': 10,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=Pasar+por+caja',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/pagar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=6BB13A944A2914598A2BB5469B2178D6',
#   'host': 'localhost:8080',
#   'index': 11,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'modo=insertar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/pagar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=6BB13A944A2914598A2BB5469B2178D6',
#   'host': 'localhost:8080',
#   'index': 11,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'precio=183',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/pagar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=6BB13A944A2914598A2BB5469B2178D6',
#   'host': 'localhost:8080',
#   'index': 11,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=Pasar+por+caja%2F',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/pagar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=837899BE3426897D2D17349939BA293C',
#   'host': 'localhost:8080',
#   'index': 12,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'modo=insertar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/pagar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=837899BE3426897D2D17349939BA293C',
#   'host': 'localhost:8080',
#   'index': 12,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'precio=183',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/pagar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=837899BE3426897D2D17349939BA293C',
#   'host': 'localhost:8080',
#   'index': 12,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1A=Pasar+por+caja',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/pagar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'modo=registro%253CSCRIPT%253Ealert%2528%2522Paros%2522%2529%253B%253C%252FSCRIPT%253E',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'login=armand',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'password=prusiato',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'nombre=Samia',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'apellidos=Catalayud+Mirabet',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'email=balademas.mareuil6%40enlanzarote.com.vc',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'dni=28178710F',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'direccion=C%2F+Cala%2C+9%2C+',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'ciudad=Mutxamel',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'cp=25332',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'provincia=Zaragoza',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'ntc=8608089924764976',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FE3FC874AFB0743B7FF01FCFA740D31F',
#   'host': 'localhost:8080',
#   'index': 13,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=Registrar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'modo=registro',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'login=armand',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'password=prusiato',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'nombre=any%250D%250ASet-cookie%253A%2BTamper%253D5765205567234876235',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'apellidos=Catalayud+Mirabet',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'email=balademas.mareuil6%40enlanzarote.com.vc',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'dni=28178710F',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'direccion=C%2F+Cala%2C+9%2C+',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'ciudad=Mutxamel',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'cp=25332',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'provincia=Zaragoza',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'ntc=8608089924764976',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=BAC1CE46C9E05E9512291182A3A3EFA8',
#   'host': 'localhost:8080',
#   'index': 14,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=Registrar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/publico/registro.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=B49F2253AD1742591711F4CCBA44EDF3',
#   'host': 'localhost:8080',
#   'index': 15,
#   'label': 'anom',
#   'method': 'GET',
# ...
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=267F0D00DAE81F2F345889A2A078DF6F',
#   'host': 'localhost:8080',
#   'index': 242,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'apellidos=Serarols+Ginesta%3C%21--%23include+file%3D%22archivo_secreto%22+--%3E',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=267F0D00DAE81F2F345889A2A078DF6F',
#   'host': 'localhost:8080',
#   'index': 242,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'email=redford2%40enlanzarote.com.cz',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=267F0D00DAE81F2F345889A2A078DF6F',
#   'host': 'localhost:8080',
#   'index': 242,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'dni=80243620R',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=267F0D00DAE81F2F345889A2A078DF6F',
#   'host': 'localhost:8080',
#   'index': 242,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'direccion=Zumel+S%2FN%2C+',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=267F0D00DAE81F2F345889A2A078DF6F',
#   'host': 'localhost:8080',
#   'index': 242,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'ciudad=Mas+de+Barberans',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=267F0D00DAE81F2F345889A2A078DF6F',
#   'host': 'localhost:8080',
#   'index': 242,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'cp=05420',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=267F0D00DAE81F2F345889A2A078DF6F',
#   'host': 'localhost:8080',
#   'index': 242,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'provincia=Zamora',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=267F0D00DAE81F2F345889A2A078DF6F',
#   'host': 'localhost:8080',
#   'index': 242,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'ntc=5782200649154235',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=267F0D00DAE81F2F345889A2A078DF6F',
#   'host': 'localhost:8080',
#   'index': 242,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=Registrar',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'modo=registro',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'login=nyberg',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'password=predicha',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'nombre=Carmina',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'apellidos=Serarols+Ginesta',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'email=redford2%40enlanzarote.com.cz',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'dni=80243620R',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'direccion=Zumel+S%2FN%2C+',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'ciudad=Mas+de+Barberans',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'cp=05420',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'provincia=Zamora',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'ntc=5782200649154235',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  {'accept': 'text/xml,application/xml,application/xhtml+xml,text/html;q=0.9,text/plain;q=0.8,image/png,*/*;q=0.5',
#   'acceptCharset': 'utf-8, utf-8;q=0.5, *;q=0.5',
#   'acceptEncoding': 'x-gzip, x-deflate, gzip, deflate',
#   'acceptLanguage': 'en',
#   'cacheControl': 'no-cache',
#   'connection': 'close',
#   'contentLength': 'NA',
#   'contentType': 'NA',
#   'cookie': 'JSESSIONID=FF2AF6C6A7BC5E2001CD9AFB1C9FBB99',
#   'host': 'localhost:8080',
#   'index': 243,
#   'label': 'anom',
#   'method': 'GET',
#   'payload': 'B1=%27%3Bwaitfor+delay+%270%3A0%3A15%27%3B--',
#   'pragma': 'no-cache',
#   'protocol': 'HTTP/1.1',
#   'url': 'http://localhost:8080/tienda1/miembros/editar.jsp',
#   'userAgent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.8 (like Gecko)'},
#  ...]

# %%
from sklearn.feature_extraction import DictVectorizer as DV

vectorizer = DV( sparse = False )
X = vectorizer.fit_transform(requests_dic)
